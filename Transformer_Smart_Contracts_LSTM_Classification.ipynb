# %%
import fastai

from fastai.callbacks import *

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('/content/gdrive/My Drive/SC Security Clean/clean_train.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-192190335b97> in <module>()
#       2 import numpy as np
#       3
# ----> 4 data = pd.read_csv('/content/gdrive/My Drive/SC Security Clean/clean_train.csv')
#       5 data.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/content/gdrive/My Drive/SC Security Clean/clean_train.csv' does not exist: b'/content/gdrive/My Drive/SC Security Clean/clean_train.csv'

# %%
len(data)
# Out:
# 892913

# %%
data.nunique()
# Out:
# ADDRESS     892913
# OPCODE       34805
# CATEGORY         5
# dtype: int64

# %%
#Select the way how you want to store the output, could be pd.DataFrame or Dict, I will use Dict to demonstrate:
col_uni_val={}
data2 = data['CATEGORY']
for i in data.columns:
    col_uni_val[i] = len(data[i].unique())

#Import pprint to display dic nicely:
import pprint
pprint.pprint(col_uni_val)
# Out:
# {'ADDRESS': 892913, 'CATEGORY': 5, 'OPCODE': 34805}

# %%
df = data.groupby('CATEGORY')['ADDRESS'].nunique()
df.head()
# Out:
# CATEGORY
# 0 0 0 1      5801
# 0 0 1 0      1461
# 0 1 0 0      1207
# 0 1 1 0       171
# 1 0 0 0    884273
# Name: ADDRESS, dtype: int64

# %%
df2 = data.groupby('CATEGORY')['OPCODE'].nunique()
df2.head()
# Out:
# CATEGORY
# 0 0 0 1     1770
# 0 0 1 0      370
# 0 1 0 0      145
# 0 1 1 0      129
# 1 0 0 0    32408
# Name: OPCODE, dtype: int64

# %%
### multi class
df = data
df_a = df.loc[df['CATEGORY'] == '1 0 0 0']
df_a2 = df_a.drop('ADDRESS', 1)
#df_a.head()
df_b = df.loc[df['CATEGORY'] == '0 0 0 1']
df_b2 = df_b.drop('ADDRESS', 1)

df_c = df.loc[df['CATEGORY'] == '0 0 1 0']
df_c2 = df_c.drop('ADDRESS', 1)
#df_c.head()

df_d = df.loc[df['CATEGORY'] == '0 1 0 0']
df_d2 = df_d.drop('ADDRESS', 1)
#df_d.head()

#df_e = df.loc[df['CATEGORY'] == '0 1 1 0']
#df_e2 = df_e.drop('ADDRESS', 1)

#df_e.head()

# %%
k1 = df_a.OPCODE.unique()
k1 = pd.DataFrame({'OPCODE' : k1 , 'CATEGORY' : '1 0 0 0'})
k1.head()
# Out:
#                                               OPCODE CATEGORY
# 0  60 60 52 36 15 61 57 60 35 7c 90 04 63 16 80 6...  1 0 0 0
# 1  60 60 52 36 15 61 57 63 7c 60 35 04 16 63 81 1...  1 0 0 0
# 2  36 60 80 37 60 60 36 60 73 60 5a 03 f4 15 60 5...  1 0 0 0
# 3  60 60 52 5b fe 00 a1 65 20 65 0a 41 82 86 95 5...  1 0 0 0
# 4  60 60 52 36 15 61 57 63 60 60 0a 60 35 04 16 6...  1 0 0 0

# %%
k2 = df_b.OPCODE.unique()
k2 = pd.DataFrame({'OPCODE' : k2 , 'CATEGORY' : '0 0 0 1'})

k3 = df_c.OPCODE.unique()
k3 = pd.DataFrame({'OPCODE' : k3 , 'CATEGORY' : '0 0 0 1'})

k4 = df_b.OPCODE.unique()
k4 = pd.DataFrame({'OPCODE' : k4 , 'CATEGORY' : '0 0 0 1'})

k5 = df_c.OPCODE.unique()
k5 = pd.DataFrame({'OPCODE' : k5 , 'CATEGORY' : '0 0 0 1'})

# %%
### binary 
k1_train = k1[0:15000]
k1_test = k1[15000:20000]

k2_train = k2[0:1500]
k2_test = k2[1500:]

k3_train = k3[0:330]
k3_test = k3[330:]

k4_train = k4[0:120]
k4_test = k4[120:]

k5_train = k5[0:100]
k5_test = k5[100:]

# %%
bin_train = pd.concat([k1_train, k2_train, k3_train, k4_train, k5_train])
bin_test = pd.concat([k1_test, k2_test, k3_test, k4_test, k5_test])
bin_train.to_csv('/content/gdrive/My Drive/DCNN/Smart Contracts/train_binary.csv')
bin_test.to_csv('/content/gdrive/My Drive/DCNN/Smart Contracts/test_binary.csv')

# %%
## multi class
k1_train = k1[0:27408]
k1_test = k1[27408:]

# %%
b_train = df_b2[0:4931]
b_test = df_b2[4931:]
c_train = df_c2[0:1241]
c_test = df_c2[1241:]
d_train = df_d2[0:1026]
d_test = df_d2[1026:]

# %%
targets = []
t1 = [3 for i in range(len(k1_test)-1)]
t2 = [0 for i in range(len(b_test)-1)]
t3 = [1 for i in range(len(c_test)-1)]
t4 = [2 for i in range(len(d_test)-1)]

# %%
t1

# %%
train = pd.concat([k1_train, b_train, c_train, d_train])
len(train)
# Out:
# 34606

# %%
test = pd.concat([k1_test, b_test, c_test, d_test])
len(test)
# Out:
# 6271

# %%
train.to_csv('/content/gdrive/My Drive/DCNN/Smart Contracts/train_final.csv')
test.to_csv('/content/gdrive/My Drive/DCNN/Smart Contracts/test_final.csv')

# %%
  
df_row_merged = pd.concat([k1, df_b2, df_c2, df_d2])
df_row_merged.head()
# Out:
#                                               OPCODE CATEGORY
# 0  60 60 52 36 15 61 57 60 35 7c 90 04 63 16 80 6...  1 0 0 0
# 1  60 60 52 36 15 61 57 63 7c 60 35 04 16 63 81 1...  1 0 0 0
# 2  36 60 80 37 60 60 36 60 73 60 5a 03 f4 15 60 5...  1 0 0 0
# 3  60 60 52 5b fe 00 a1 65 20 65 0a 41 82 86 95 5...  1 0 0 0
# 4  60 60 52 36 15 61 57 63 60 60 0a 60 35 04 16 6...  1 0 0 0

# %%
########### MAIN CODE

import pandas as pd
import numpy as np
df_row_merged = pd.read_csv('/content/gdrive/My Drive/DCNN/Smart Contracts/train_binary.csv')
df_row_merged.head()
df = df_row_merged

# %%
len(df_row_merged)
# Out:
# 17050

# %%
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
from fastai.text import *
from nltk import tokenize

# %%
# Create databunch

df = df_row_merged
data = (TextList.from_df(df, cols='OPCODE')
                .split_by_rand_pct(0.2)
                .label_for_lm()  
                .databunch(bs=48))
data.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>61 57 7f 60 60 90 54 90 61 0a 90 04 73 16 60 51 80 82 73 16 73 16 81 52 60 01 91 50 50 60 51 80 91 03 90 a1 61 56 5b 60 60 fd 5b 5b 56 5b 00 5b 34 15 61 57 fe 5b 61 60 80 80 35 73 16 90 60 01 90 91 90 50 50 61</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>04 02 83 52 91 60 01 91 61 56 5b 82 01 91 90 60 52 60 60 20 90 5b 81 54 81 52 90 60 01 90 60 01 80 83 11 61 57 82 90 03 60 16 82 01 91 5b xxwrep 5 50 90 50 61 56 5b 90 56 5b 80 60 60 50 90 80 51 90 60 01 90 82 80</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>91 03 90 f3 5b 34 15 61 57 60 80 fd 5b 61 61 56 5b 00 5b 34 15 61 57 60 80 fd 5b 61 61 56 5b 60 51 80 82 81 52 60 01 91 50 50 60 51 80 91 03 90 f3 5b 34 15 61 57 60 80 fd 5b 61 60 80 80 35 73 16 90 60 01 90 91</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>81 52 60 90 91 01 90 60 01 80 83 11 61 57 5b xxwrep 5 50 90 50 94 50 94 50 94 50 94 50 94 50 5b 91 93 95 90 92 94 50 56 5b 61 61 56 5b 60 80 54 80 60 02 60 01 60 51 90 81 01 60 52 80 92 91 90 81 81 52 60 01 82 80</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>61 57 60 80 fd 5b 60 60 90 54 90 61 0a 90 04 73 16 73 16 61 82 90 81 15 02 90 60 51 60 60 51 80 83 03 81 85 88 88 f1 93 xxwrep 4 50 15 15 61 57 60 80 fd 5b 5b 5b 50 56 5b 60 80 82 84 02 90 50 60 84 14 80 61 57 50</td>
#     </tr>
#   </tbody>
# </table>

# %%
data_lm = data
learn = language_model_learner(data_lm, Transformer, drop_mult=0.3)
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-modelzoo/transformer

# %%
import warnings
warnings.simplefilter("error")
warnings.simplefilter("ignore")

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='94' class='' max='7115', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.32% [94/7115 00:50<1:03:13 20.9730]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(4, 1e-2, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.496322</td>
#       <td>1.479724</td>
#       <td>0.609404</td>
#       <td>1:10:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.543662</td>
#       <td>1.526901</td>
#       <td>0.598133</td>
#       <td>1:10:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.349477</td>
#       <td>1.175396</td>
#       <td>0.683902</td>
#       <td>1:10:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.168987</td>
#       <td>1.101891</td>
#       <td>0.702656</td>
#       <td>1:10:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
path_models1 = '/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/Transformer/'

# %%
learn.save_encoder(path_models1 + 'initial_enc-4-epochs-complete')

# %%
learn.save(path_models1 + 'fit_head')

# %%
learn.load(path_models1 + 'fit_head');

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(3, 9e-3, moms=(0.8,0.7))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2477' class='' max='7080', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       34.99% [2477/7080 29:59<55:44 3.4363]
#     </div>

# %%
learn.save(path_models1 + 'fit_head_2')

# %%
learn.save_encoder(path_models1 + 'initial_enc-4-epochs-1e-3-complete-2')

# %%
learn.load(path_models1 + 'fit_head_2');

# %%
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.422353</td>
#       <td>3.447766</td>
#       <td>0.160537</td>
#       <td>1:33:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(path_models1 + 'fine_tuned-ver-2')
learn.save_encoder(path_models1 + 'initial_enc-7-epochs-1e-3-complete-2')

# %%
learn.load_encoder(path_models1 + 'initial_enc-7-epochs-1e-3-complete-2');

# %%
learn.load(path_models1 + 'fine_tuned-ver-2');

# %%
learn.fit_one_cycle(2, 3e-2, moms=(0.8,0.7))

# %%
learn.save(path_models1 + 'fine_tuned-final')
learn.save_encoder(path_models1 + 'initial_enc-9-epochs-3e-2-complete-2')

# %%
############# Classifier
###########  Main code for classifier data

bs = 32

data_lm = data
csv_path = '/content/gdrive/My Drive/DCNN/Smart Contracts/'
classifier_data = (TextList.from_df(df, csv_path, cols=['OPCODE','CATEGORY'], vocab=data_lm.vocab)
                    .split_by_rand_pct(0.18, seed = 42)
                    .label_from_df(cols='CATEGORY', label_delim='|')
                    .databunch(bs=bs))
#path_models = '/content/gdrive/My Drive/Smart Contracts/models/Smart_Contracts'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b4ec5862348c> in <module>()
#       2 bs = 32
#       3
# ----> 4 data_lm = data
#       5 csv_path = '/content/gdrive/My Drive/DCNN/Smart Contracts/'
#       6 classifier_data = (TextList.from_df(df, csv_path, cols=['OPCODE','CATEGORY'], vocab=data_lm.vocab)
#
# NameError: name 'data' is not defined

# %%
test_df = pd.read_csv('/content/gdrive/My Drive/DCNN/Smart Contracts/test_binary.csv')
classifier_data.add_test(test_df['OPCODE'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-19c92d9fa292> in <module>()
#       1 test_df = pd.read_csv('/content/gdrive/My Drive/DCNN/Smart Contracts/test_binary.csv')
# ----> 2 classifier_data.add_test(test_df['OPCODE'])
#
# NameError: name 'classifier_data' is not defined

# %%
#classifier_data.add_test(k1['OPCODE'])

# %%
learner = text_classifier_learner(classifier_data, Transformer, drop_mult=1.0, metrics=fbeta)

# %%
#learner.load_encoder(path_models + 'initial_enc-2-epochs-1e-3-complete-2')
#path_models = '/content/gdrive/My Drive/smart contracts/models/'

#path_models1 = '/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/encoder/'
path_models1 = '/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/Transformer/'


learner.load_encoder(path_models1 + 'initial_enc-7-epochs-1e-3-complete-2');


##learner.load_encoder(path_models1 + 'initial_enc-9-epochs-3e-2-complete-2');
learner.freeze()

# %%
## Learning Rate Scheduler for Classifier
learner.lr_find()
learner.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='94' class='' max='436', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.56% [94/436 01:26<05:15 1.2983]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 4e-2
learner.fit_one_cycle(2,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.339609</td>
#       <td>0.803276</td>
#       <td>0.785544</td>
#       <td>08:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.320935</td>
#       <td>0.408463</td>
#       <td>0.885739</td>
#       <td>10:51</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-2-epochs-4e-2')

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/classifier2/classifier-2-epochs-8e-2');

# %%
learner.freeze_to(-2)
lr = 3e-2
learner.fit_one_cycle(6,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.294809</td>
#       <td>0.236878</td>
#       <td>0.933203</td>
#       <td>11:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.270762</td>
#       <td>0.255503</td>
#       <td>0.933149</td>
#       <td>10:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.245985</td>
#       <td>0.222976</td>
#       <td>0.939720</td>
#       <td>11:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.243970</td>
#       <td>0.316320</td>
#       <td>0.919898</td>
#       <td>12:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.241043</td>
#       <td>0.207792</td>
#       <td>0.949658</td>
#       <td>10:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.200038</td>
#       <td>0.268029</td>
#       <td>0.950418</td>
#       <td>10:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-8-epochs-3e-2')

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/classifier/classifier-5-epochs-4e-2');

# %%
learner.freeze_to(-2)
lr = 3e-2
learner.fit_one_cycle(3,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.239654</td>
#       <td>0.615458</td>
#       <td>0.947214</td>
#       <td>09:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.215753</td>
#       <td>0.226246</td>
#       <td>0.947594</td>
#       <td>10:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.203051</td>
#       <td>0.175499</td>
#       <td>0.951178</td>
#       <td>09:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-11-epochs-3e-2')

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-11-epochs-3e-2');

# %%
learner.freeze_to(-2)
lr = 2e-2
learner.fit_one_cycle(5,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )

# %%
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-16-epochs-2e-2-over')

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-16-epochs-2e-2-over');

# %%
learner.freeze_to(-2)
lr = 1e-2
learner.fit_one_cycle(5,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )

# %%
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-21-epochs-1e-2')

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-21-epochs-1e-2');

# %%
learner.freeze_to(-2)
lr = 1e-2
learner.fit_one_cycle(8,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.179479</td>
#       <td>0.175261</td>
#       <td>0.954220</td>
#       <td>11:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.195685</td>
#       <td>0.228402</td>
#       <td>0.950690</td>
#       <td>14:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.200891</td>
#       <td>0.169873</td>
#       <td>0.954111</td>
#       <td>13:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.200201</td>
#       <td>0.158785</td>
#       <td>0.958944</td>
#       <td>13:53</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.189233</td>
#       <td>0.172423</td>
#       <td>0.956066</td>
#       <td>12:51</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.203847</td>
#       <td>0.157931</td>
#       <td>0.958944</td>
#       <td>11:26</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.171697</td>
#       <td>0.159981</td>
#       <td>0.956229</td>
#       <td>12:28</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.182342</td>
#       <td>0.168691</td>
#       <td>0.957152</td>
#       <td>12:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-29-epochs-1e-2')

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-29-epochs-1e-2');

# %%
learner.freeze_to(-2)
lr = 3e-2
learner.fit_one_cycle(8,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-37-epochs-3e-2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.179375</td>
#       <td>0.441404</td>
#       <td>0.952536</td>
#       <td>11:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.217570</td>
#       <td>0.174552</td>
#       <td>0.951830</td>
#       <td>14:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.241806</td>
#       <td>0.173101</td>
#       <td>0.954654</td>
#       <td>13:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.221571</td>
#       <td>0.452665</td>
#       <td>0.955414</td>
#       <td>13:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.197854</td>
#       <td>0.179442</td>
#       <td>0.953677</td>
#       <td>12:53</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.210999</td>
#       <td>0.170665</td>
#       <td>0.954437</td>
#       <td>11:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.174737</td>
#       <td>0.157972</td>
#       <td>0.957587</td>
#       <td>12:30</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.192352</td>
#       <td>0.159834</td>
#       <td>0.958075</td>
#       <td>12:55</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-37-epochs-3e-2');

# %%
##############################################
learner.freeze_to(-3)
lr = 2e-2
learner.fit_one_cycle(8,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-45-epochs-2e-2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.204994</td>
#       <td>0.168397</td>
#       <td>0.955034</td>
#       <td>14:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.232284</td>
#       <td>0.178045</td>
#       <td>0.954491</td>
#       <td>16:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.235496</td>
#       <td>0.177318</td>
#       <td>0.952807</td>
#       <td>16:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.217471</td>
#       <td>2.992480</td>
#       <td>0.945802</td>
#       <td>15:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.203955</td>
#       <td>0.193288</td>
#       <td>0.951124</td>
#       <td>17:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.196111</td>
#       <td>0.161320</td>
#       <td>0.955903</td>
#       <td>17:54</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.205629</td>
#       <td>0.149910</td>
#       <td>0.961334</td>
#       <td>15:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.167945</td>
#       <td>0.147319</td>
#       <td>0.960736</td>
#       <td>15:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-45-epochs-2e-2');
learner.freeze_to(-3)
lr = 9e-3
learner.fit_one_cycle(8,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-53-epochs-2e-2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.158206</td>
#       <td>0.142008</td>
#       <td>0.963343</td>
#       <td>13:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.176133</td>
#       <td>0.132934</td>
#       <td>0.964972</td>
#       <td>12:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.170945</td>
#       <td>0.137159</td>
#       <td>0.962311</td>
#       <td>11:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.168392</td>
#       <td>0.139491</td>
#       <td>0.963723</td>
#       <td>11:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.153304</td>
#       <td>0.189117</td>
#       <td>0.961225</td>
#       <td>12:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.132641</td>
#       <td>0.122213</td>
#       <td>0.968068</td>
#       <td>14:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.139724</td>
#       <td>2.017439</td>
#       <td>0.941620</td>
#       <td>11:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.140328</td>
#       <td>0.113210</td>
#       <td>0.970566</td>
#       <td>11:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-53-epochs-2e-2');learner.freeze_to(-3)
lr = 9e-3
learner.fit_one_cycle(8,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-60-epochs-2e-2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.128073</td>
#       <td>0.119002</td>
#       <td>0.968557</td>
#       <td>17:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.166349</td>
#       <td>0.134227</td>
#       <td>0.966058</td>
#       <td>16:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.163422</td>
#       <td>0.139112</td>
#       <td>0.965569</td>
#       <td>18:56</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.173766</td>
#       <td>0.286472</td>
#       <td>0.956175</td>
#       <td>18:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.134874</td>
#       <td>0.138193</td>
#       <td>0.962257</td>
#       <td>17:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.124796</td>
#       <td>0.121065</td>
#       <td>0.968774</td>
#       <td>19:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.129993</td>
#       <td>0.112160</td>
#       <td>0.970783</td>
#       <td>20:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.125925</td>
#       <td>0.115919</td>
#       <td>0.969534</td>
#       <td>17:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-60-epochs-2e-2');
learner.freeze_to(-3)
lr = 2e-2
learner.fit_one_cycle(5,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-65-epochs-2e-2');
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.170314</td>
#       <td>0.190675</td>
#       <td>0.960030</td>
#       <td>18:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.206596</td>
#       <td>0.154648</td>
#       <td>0.960085</td>
#       <td>16:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.191065</td>
#       <td>0.146961</td>
#       <td>0.963777</td>
#       <td>19:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.174279</td>
#       <td>0.129026</td>
#       <td>0.966601</td>
#       <td>19:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.146621</td>
#       <td>0.276548</td>
#       <td>0.965081</td>
#       <td>17:55</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-65-epochs-2e-2');
learner.freeze_to(-3)
lr = 1e-2
learner.fit_one_cycle(5,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-70-epochs-1e-2');
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.152110</td>
#       <td>0.131252</td>
#       <td>0.966493</td>
#       <td>18:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.168619</td>
#       <td>0.138271</td>
#       <td>0.964266</td>
#       <td>16:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.153533</td>
#       <td>0.132126</td>
#       <td>0.965950</td>
#       <td>19:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.153247</td>
#       <td>0.125915</td>
#       <td>0.968448</td>
#       <td>18:34</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.126421</td>
#       <td>0.133203</td>
#       <td>0.965081</td>
#       <td>17:30</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-70-epochs-1e-2');
learner.freeze_to(-3)
lr = 1e-2
learner.fit_one_cycle(5,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-75-epochs-1e-2');
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.172612</td>
#       <td>0.141130</td>
#       <td>0.963723</td>
#       <td>17:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.183975</td>
#       <td>0.193879</td>
#       <td>0.957261</td>
#       <td>15:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.160322</td>
#       <td>0.133809</td>
#       <td>0.965190</td>
#       <td>18:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.158105</td>
#       <td>0.127668</td>
#       <td>0.965135</td>
#       <td>17:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.135397</td>
#       <td>0.130286</td>
#       <td>0.965895</td>
#       <td>16:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-75-epochs-1e-2');
learner.freeze_to(-3)
lr = 1e-2
learner.fit_one_cycle(5,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-80-epochs-1e-2');
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.154789</td>
#       <td>0.132981</td>
#       <td>0.964755</td>
#       <td>19:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.172867</td>
#       <td>1.144554</td>
#       <td>0.963778</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.166466</td>
#       <td>0.122510</td>
#       <td>0.968230</td>
#       <td>20:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.159537</td>
#       <td>0.123722</td>
#       <td>0.967742</td>
#       <td>20:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.129896</td>
#       <td>0.121392</td>
#       <td>0.967579</td>
#       <td>18:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-80-epochs-1e-2');
learner.freeze_to(-3)
lr = 1e-2
learner.fit_one_cycle(10,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-90-epochs-1e-2');
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.177238</td>
#       <td>0.148695</td>
#       <td>0.960302</td>
#       <td>12:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.177051</td>
#       <td>0.139857</td>
#       <td>0.962692</td>
#       <td>11:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.161684</td>
#       <td>0.135425</td>
#       <td>0.964918</td>
#       <td>13:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.174451</td>
#       <td>0.124701</td>
#       <td>0.968068</td>
#       <td>12:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.155101</td>
#       <td>0.135842</td>
#       <td>0.961334</td>
#       <td>11:57</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.153178</td>
#       <td>0.132065</td>
#       <td>0.965081</td>
#       <td>13:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.154783</td>
#       <td>0.121194</td>
#       <td>0.966601</td>
#       <td>13:46</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.155945</td>
#       <td>0.118097</td>
#       <td>0.967525</td>
#       <td>11:50</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.133530</td>
#       <td>0.120655</td>
#       <td>0.966873</td>
#       <td>11:42</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.150391</td>
#       <td>0.121996</td>
#       <td>0.967036</td>
#       <td>11:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.load('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-90-epochs-1e-2');
learner.freeze_to(-3)
lr = 2e-2
learner.fit_one_cycle(10,slice(lr/(2.6**4),lr), moms=(0.8,0.7) )
learner.save('/content/gdrive/My Drive/DCNN/Smart Contracts/weights2/binary/classifier-100-epochs-2e-2');
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='408' class='' max='436', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       93.58% [408/436 10:30<00:43 0.1410]
#     </div>

# %%
predictions, *_ = learner.get_preds(DatasetType.Test)

# %%
preds = np.argmax(predictions, axis = 1)

# %%
preds

# %%
preds_test = np.argmax(predictions, axis = 1)

# %%
preds_test
# Out:
# tensor([1, 1, 1,  ..., 1, 1, 1])

# %%
your_file = open('/content/gdrive/My Drive/DCNN/Smart Contracts/filename2.txt', 'ab')
np.savetxt(your_file, preds_test.numpy())
your_file.close()

# %%
####binary
ta = [1 for i in range(5000)]
a12 = len(preds_test)-5000
tb = [0 for i in range(a12)]
arr = ta+tb
arr = np.asarray(arr)

# %%
targets = []
t1 = [3 for i in range(5000)]
t2 = [0 for i in range(870)]
t3 = [1 for i in range(220)]
t4 = [2 for i in range(181)]
arr = t1+t2+t3+t4
arr = np.asarray(arr)
len(arr)
# Out:
# 6271

# %%
import torch
target = torch.from_numpy(arr)
target

# %%
target1 = torch.nn.functional.one_hot(target)
target1

# %%
## testing 100 epochs
from sklearn.metrics import classification_report
print(classification_report(target, preds_test))

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(target, preds_test)
cm

# %%
## testing latest
from sklearn.metrics import classification_report
print(classification_report(target, preds_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85      2230
#            1       0.92      0.95      0.94      5000
#
#     accuracy                           0.91      7230
#    macro avg       0.90      0.89      0.89      7230
# weighted avg       0.91      0.91      0.91      7230

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(target, preds_test)
cm
# Out:
# array([[1829,  401],
#        [ 236, 4764]])

# %%
preds1, targets1 = learner.get_preds()

# %%
preds = np.argmax(preds1, axis = 1)

# %%
preds1
# Out:
# tensor([3, 3, 3,  ..., 2, 3, 0])

# %%
targs = np.argmax(targets1, axis = 1)

# %%
## testing
from sklearn.metrics import classification_report
print(classification_report(target, preds_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.08      0.03      0.04      5000
#            1       0.12      0.30      0.17      2230
#
#     accuracy                           0.11      7230
#    macro avg       0.10      0.16      0.11      7230
# weighted avg       0.09      0.11      0.08      7230

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(target, preds_test)
cm
# Out:
# array([[ 140, 4860],
#        [1559,  671]])

# %%
### validation

from sklearn.metrics import classification_report
print(classification_report(targs, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       731
#            1       0.97      0.88      0.92       201
#            2       0.96      0.92      0.94       143
#            3       0.98      0.99      0.98      4115
#
#     accuracy                           0.97      5190
#    macro avg       0.96      0.93      0.95      5190
# weighted avg       0.97      0.97      0.97      5190

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(target, preds_test)

# %%
cm
# Out:
# array([[ 562,   89,    0,  219],
#        [  24,   62,    0,  134],
#        [   0,    4,  138,   39],
#        [  88,  165,    4, 4743]])

# %%
targets = target
preds = predictions

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = 4

targets = target1
preds = predictions

y_test = targets.numpy()
y_score = preds.numpy()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
plt.figure()
lw = 2
plt.plot(fpr[2], tpr[2], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[2])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
fpr
# Out:
# {0: array([0.      , 0.      , 0.      , 0.      , ..., 0.991853, 0.994631, 0.997223, 1.      ]),
#  1: array([0.      , 0.      , 0.      , 0.      , ..., 0.99339 , 0.99372 , 0.997191, 1.      ]),
#  2: array([0.      , 0.002463, 0.002463, 0.002463, ..., 0.994581, 0.996223, 0.996552, 1.      ]),
#  3: array([0.      , 0.      , 0.      , 0.      , ..., 0.992919, 0.996853, 0.998426, 1.      ]),
#  'micro': array([0.000000e+00, 7.973210e-04, 7.973210e-04, 7.973210e-04, ..., 9.969170e-01, 9.970233e-01, 9.982990e-01,
#         1.000000e+00])}

# %%
# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
#all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
all_fpr = np.unique(np.concatenate([fpr[0], fpr[1], fpr[2], fpr[3]]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
mean_tpr = interp(all_fpr, fpr[0], tpr[0]) + interp(all_fpr, fpr[1], tpr[1]) + interp(all_fpr, fpr[2], tpr[2]) + interp(all_fpr, fpr[3], tpr[3]) 
#for i in range(n_classes):
    #mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
n_c = 5
#mean_tpr /= n_classes
mean_tpr /= n_c

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['red', 'green', 'blue','yellow','yellow'])
for i, color in zip(range(n_classes), colors):
  if i != 10:
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of Type {0} '
             ''.format(i, roc_auc[i]))
##(area = {1:0.2f})

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
#plt.xticks(fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
#plt.title('Receiver operating characteristic to multi-class classification')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   """

# %%
plt.figure()


colors = cycle(['red', 'green', 'blue','orange'])
for i, color in zip(range(n_classes), colors):
  if i != 10:
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of Type {0} (Area = {1:0.4f})'
             ''.format(i+1, roc_auc[i]))
## 

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
#plt.xticks(fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
#plt.title('Receiver operating characteristic to multi-class classification')
plt.legend(loc="lower right")
plt.show()
